# %%
import netCDF4 as nc
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
datapath = "/work/aes/OM4_025/frazil_diag/"
hfsifrazil = nc.Dataset(datapath + "19000101.ocean_annual.nc").variables["hfsifrazil"][0,:,:]
frazil_heat_tendency_2d = nc.Dataset(datapath + "19000101.ocean_annual.nc").variables["frazil_heat_tendency_2d"][0,:,:]
frazil_heat_tendency = nc.Dataset(datapath + "19000101.ocean_annual_z.nc").variables["frazil_heat_tendency"][0,:,:,:]

# %%
plt.pcolormesh(frazil_heat_tendency.sum(axis=0)-hfsifrazil)
plt.colorbar()

# %%
plt.pcolormesh(frazil_heat_tendency_2d-hfsifrazil)
plt.colorbar()

# %%
np.max(np.abs(frazil_heat_tendency.sum(axis=0)-hfsifrazil))
# Out:
# 0.00024414062
