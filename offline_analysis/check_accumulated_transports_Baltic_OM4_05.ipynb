# %%
import numpy as np
import netCDF4 as nc
import matplotlib.pyplot as plt
from math import fsum
# %matplotlib notebook

# %%
inpath = '/home/aes/git/ashao_forks/MOM6-examples/ice_ocean_SIS2/Baltic_OM4_05/'
in_native_1day = inpath + '20000201.off_sum_1day.nc'
in_z_1day = inpath + '20000201.off_sum_1day_z.nc'
in_native_30day = inpath + '20000201.off_sum_30day.nc'
in_z_30day = inpath + '20000201.off_sum_30day_z.nc'

# %%
uhtr_native_1day = nc.Dataset(in_native_1day).variables['uhtr_sum'][:,:,:,:].sum(axis=0)
uhtr_z_1day = nc.Dataset(in_z_1day).variables['uhtr_sum'][:,:,:,:].sum(axis=0)
uhtr_native_30day = nc.Dataset(in_native_30day).variables['uhtr_sum'][:,:,:,:].sum(axis=0)
uhtr_z_30day = nc.Dataset(in_z_30day).variables['uhtr_sum'][:,:,:,:].sum(axis=0)

# %%
plt.figure()
plt.pcolormesh( uhtr_native_30day.sum(axis=0)-uhtr_z_30day.sum(axis=0)); plt.colorbar()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure()
plt.pcolormesh( uhtr_native_1day.sum(axis=0)-uhtr_z_30day.sum(axis=0)); plt.colorbar()
# Out:
# <img src="data:image/png;base64,...">

# %%
np.argmax?

# %%
surf_u = np.abs(uhtr_10day[0,:,:])
maxinds = np.unravel_index(surf_u.argmax(),surf_u.shape)

# %%
surf_u[maxinds]
# Out:
# 409752581350.89154

# %%
uhtr_1day[0,maxinds[0],maxinds[1]]
# Out:
# -619527284690.57251

# %%
uhtr_5day[0,maxinds[0],maxinds[1]]
# Out:
# -590846768885.55261

# %%
uhtr_10day[0,maxinds[0],maxinds[1]]
# Out:
# -409752581350.89154

# %%
uhtr_30day[0,maxinds[0],maxinds[1]]
# Out:
# -214518287854.72156

# %%
fsum(uhtr_1day[:,0,maxinds[0],maxinds[1]])
# Out:
# -619527284690.5724

# %%
plt.figure()
plt.subplot(1,2,1)
plt.plot(time_1day,uhtr_1day[:,0,maxinds[0],maxinds[1]].cumsum())
plt.plot(time_5day,uhtr_5day[:,0,maxinds[0],maxinds[1]].cumsum())
plt.subplot(1,2,2)
# Out:
# <img src="data:image/png;base64,...">

# %%
uhtr_5day[:,0,maxinds[0],maxinds[1]].cumsum().shape
# Out:
# (5,)
